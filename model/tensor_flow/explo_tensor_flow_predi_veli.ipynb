# %% [markdown]
# # Explo TF Prédi-Véli
#
# Basic task:
# 1. take raw data from 8:40, 8:50 and 9:00
# 2. predict number of free docks at 9:30.

# %% [markdown]
# ## Load and prepare data

# %%
import pandas as pd
from pathlib import Path

features_source_path = Path()/"data_source/summary_features_2023-02-11.parquet"
labels_source_path = Path()/"data_source/summary_labels_2023-02-17.parquet"

# %%
df = pd.read_parquet(features_source_path)

# %%
df
# Out:
#                           stationCode  available_mechanical  \
# file_time
# 2022-05-20 08:40:08+02:00       18024                   3.0
# 2022-05-20 08:40:08+02:00       19040                   1.0
# 2022-05-20 08:40:08+02:00       26001                  11.0
# 2022-05-20 08:40:08+02:00       17047                   0.0
# 2022-05-20 08:40:08+02:00        6016                   5.0
# ...                               ...                   ...
# 2023-02-11 09:00:07+01:00       11041                   0.0
# 2023-02-11 09:00:07+01:00       19039                   0.0
# 2023-02-11 09:00:07+01:00       21703                   0.0
# 2023-02-11 09:00:07+01:00       35017                   3.0
# 2023-02-11 09:00:07+01:00       18029                   3.0
#
#                            available_electrical  local_hour  local_minute  \
# file_time
# 2022-05-20 08:40:08+02:00                   4.0           8            40
# 2022-05-20 08:40:08+02:00                   2.0           8            40
# 2022-05-20 08:40:08+02:00                   8.0           8            40
# 2022-05-20 08:40:08+02:00                   1.0           8            40
# 2022-05-20 08:40:08+02:00                   1.0           8            40
# ...                                         ...         ...           ...
# 2023-02-11 09:00:07+01:00                   0.0           9             0
# 2023-02-11 09:00:07+01:00                   5.0           9             0
# 2023-02-11 09:00:07+01:00                   0.0           9             0
# 2023-02-11 09:00:07+01:00                   1.0           9             0
# 2023-02-11 09:00:07+01:00                  12.0           9             0
#
#                            week_day        date
# file_time
# 2022-05-20 08:40:08+02:00         4  2022-05-20
# 2022-05-20 08:40:08+02:00         4  2022-05-20
# 2022-05-20 08:40:08+02:00         4  2022-05-20
# 2022-05-20 08:40:08+02:00         4  2022-05-20
# 2022-05-20 08:40:08+02:00         4  2022-05-20
# ...                             ...         ...
# 2023-02-11 09:00:07+01:00         5  2023-02-11
# 2023-02-11 09:00:07+01:00         5  2023-02-11
# 2023-02-11 09:00:07+01:00         5  2023-02-11
# 2023-02-11 09:00:07+01:00         5  2023-02-11
# 2023-02-11 09:00:07+01:00         5  2023-02-11
#
# [1020887 rows x 7 columns]

# %%
df["local_minute"].unique()
# Out:
# array([40, 50,  0], dtype=int64)

# %%
len(df["stationCode"].unique())
# Out:
# 1468

# %% [markdown]
# ## Naïve attempt: all stations, all time
#
# Model:
# * input = all stations, mechanical and electrical, 9:00
# * output = all stations, free docks, 9:30
#
# NB: test this, check where it fails (if it fails!) and use it as benchmark for the rest.

# %% [markdown]
# ### Preparing features

# %%
input_mask = (df["local_hour"]==9) & (df["local_minute"]==0)
raw_input = df[input_mask]

# %%
input_mech_col = ["available_mechanical", "date", "stationCode"]

input_mech_by_date = raw_input[input_mech_col].pivot(index=["date"], columns=["stationCode"])

# %%
input_elec_col = ["available_electrical", "date", "stationCode"]

input_elec_by_date = raw_input[input_elec_col].pivot(index=["date"], columns=["stationCode"])

# %%
input_mech_by_date.shape
# Out:
# (235, 1468)

# %%
input_elec_by_date.shape
# Out:
# (235, 1468)

# %%
input_ini = input_elec_by_date.join(input_mech_by_date)

# %%
input_ini.columns
# Out:
# MultiIndex([('available_electrical', '10001'),
#             ('available_electrical', '10003'),
#             ('available_electrical', '10004'),
#             ('available_electrical', '10005'),
#             ('available_electrical', '10006'),
#             ('available_electrical', '10008'),
#             ('available_electrical', '10009'),
#             ('available_electrical',  '1001'),
#             ('available_electrical', '10010'),
#             ('available_electrical', '10011'),
#             ...
#             ('available_mechanical',  '9117'),
#             ('available_mechanical',  '9118'),
#             ('available_mechanical', '92001'),
#             ('available_mechanical', '92002'),
#             ('available_mechanical', '92003'),
#             ('available_mechanical', '92004'),
#             ('available_mechanical', '92005'),
#             ('available_mechanical', '92006'),
#             ('available_mechanical', '92007'),
#             ('available_mechanical', '92008')],
#            names=[None, 'stationCode'], length=2936)

# %% [markdown]
# ### Preparing labels

# %%
raw_labels = pd.read_parquet(labels_source_path)

# %%
raw_labels["date"] = pd.to_datetime(raw_labels["date"])

# %%
raw_labels["stationCode"]
# Out:
# file_time
# 2022-05-20 09:30:08+02:00     5001
# 2022-05-20 09:30:08+02:00    20044
# 2022-05-20 09:30:08+02:00    14031
# 2022-05-20 09:30:08+02:00     6002
# 2022-05-20 09:30:08+02:00    41401
#                              ...
# 2023-02-11 09:30:08+01:00    19038
# 2023-02-11 09:30:08+01:00    18109
# 2023-02-11 09:30:08+01:00    19009
# 2023-02-11 09:30:08+01:00    10020
# 2023-02-11 09:30:08+01:00    16107
# Name: stationCode, Length: 340778, dtype: string

# %%
# To compute available free docks, need station capacity!

data_folder = Path()/"../../data/"

station_infos_list = sorted(list(data_folder.glob('station_info*.csv')))

station_infos_list
# Out:
# [WindowsPath('../../data/station_info_2022-05-15.csv'),
#  WindowsPath('../../data/station_info_2022-05-16.csv'),
#  WindowsPath('../../data/station_info_2022-05-17.csv'),
#  WindowsPath('../../data/station_info_2022-05-18.csv'),
#  WindowsPath('../../data/station_info_2022-05-19.csv'),
#  WindowsPath('../../data/station_info_2022-05-20.csv'),
#  WindowsPath('../../data/station_info_2022-05-21.csv'),
#  WindowsPath('../../data/station_info_2022-05-22.csv'),
#  WindowsPath('../../data/station_info_2022-05-23.csv'),
#  WindowsPath('../../data/station_info_2022-05-24.csv'),
#  WindowsPath('../../data/station_info_2022-05-25.csv'),
#  WindowsPath('../../data/station_info_2022-05-26.csv'),
#  WindowsPath('../../data/station_info_2022-05-27.csv'),
#  WindowsPath('../../data/station_info_2022-05-28.csv'),
#  WindowsPath('../../data/station_info_2022-05-29.csv'),
#  WindowsPath('../../data/station_info_2022-05-30.csv'),
#  WindowsPath('../../data/station_info_2022-05-31.csv'),
#  WindowsPath('../../data/station_info_2022-06-01.csv'),
#  WindowsPath('../../data/station_info_2022-06-02.csv'),
#  WindowsPath('../../data/station_info_2022-06-03.csv'),
#  WindowsPath('../../data/station_info_2022-06-04.csv'),
#  WindowsPath('../../data/station_info_2022-06-05.csv'),
#  WindowsPath('../../data/station_info_2022-06-06.csv'),
#  WindowsPath('../../data/station_info_2022-06-07.csv'),
#  WindowsPath('../../data/station_info_2022-06-08.csv'),
#  WindowsPath('../../data/station_info_2022-06-09.csv'),
#  WindowsPath('../../data/station_info_2022-06-10.csv'),
#  WindowsPath('../../data/station_info_2022-06-11.csv'),
#  WindowsPath('../../data/station_info_2022-06-12.csv'),
#  WindowsPath('../../data/station_info_2022-06-13.csv'),
#  WindowsPath('../../data/station_info_2022-06-14.csv'),
#  WindowsPath('../../data/station_info_2022-06-15.csv'),
#  WindowsPath('../../data/station_info_2022-06-16.csv'),
#  WindowsPath('../../data/station_info_2022-06-17.csv'),
#  WindowsPath('../../data/station_info_2022-06-18.csv'),
#  WindowsPath('../../data/station_info_2022-06-19.csv'),
#  WindowsPath('../../data/station_info_2022-06-20.csv'),
#  WindowsPath('../../data/station_info_2022-06-21.csv'),
#  WindowsPath('../../data/station_info_2022-06-22.csv'),
#  WindowsPath('../../data/station_info_2022-06-23.csv'),
#  WindowsPath('../../data/station_info_2022-06-24.csv'),
#  WindowsPath('../../data/station_info_2022-06-25.csv'),
#  WindowsPath('../../data/station_info_2022-06-26.csv'),
#  WindowsPath('../../data/station_info_2022-06-27.csv'),
#  WindowsPath('../../data/station_info_2022-06-28.csv'),
#  WindowsPath('../../data/station_info_2022-06-29.csv'),
#  WindowsPath('../../data/station_info_2022-06-30.csv'),
#  WindowsPath('../../data/station_info_2022-07-01.csv'),
#  WindowsPath('../../data/station_info_2022-07-02.csv'),
#  WindowsPath('../../data/station_info_2022-07-03.csv'),
#  WindowsPath('../../data/station_info_2022-07-04.csv'),
#  WindowsPath('../../data/station_info_2022-07-05.csv'),
#  WindowsPath('../../data/station_info_2022-07-06.csv'),
#  WindowsPath('../../data/station_info_2022-07-07.csv'),
#  WindowsPath('../../data/station_info_2022-07-08.csv'),
#  WindowsPath('../../data/station_info_2022-07-09.csv'),
#  WindowsPath('../../data/station_info_2022-07-10.csv'),
#  WindowsPath('../../data/station_info_2022-07-11.csv'),
#  WindowsPath('../../data/station_info_2022-07-12.csv'),
#  WindowsPath('../../data/station_info_2022-07-13.csv'),
#  WindowsPath('../../data/station_info_2022-07-14.csv'),
#  WindowsPath('../../data/station_info_2022-07-15.csv'),
#  WindowsPath('../../data/station_info_2022-07-16.csv'),
#  WindowsPath('../../data/station_info_2022-07-17.csv'),
#  WindowsPath('../../data/station_info_2022-07-18.csv'),
#  WindowsPath('../../data/station_info_2022-07-19.csv'),
#  WindowsPath('../../data/station_info_2022-07-20.csv'),
#  WindowsPath('../../data/station_info_2022-07-21.csv'),
#  WindowsPath('../../data/station_info_2022-07-22.csv'),
#  WindowsPath('../../data/station_info_2022-07-23.csv'),
#  WindowsPath('../../data/station_info_2022-07-24.csv'),
#  WindowsPath('../../data/station_info_2022-07-25.csv'),
#  WindowsPath('../../data/station_info_2022-07-26.csv'),
#  WindowsPath('../../data/station_info_2022-07-27.csv'),
#  WindowsPath('../../data/station_info_2022-07-28.csv'),
#  WindowsPath('../../data/station_info_2022-07-29.csv'),
#  WindowsPath('../../data/station_info_2022-07-30.csv'),
#  WindowsPath('../../data/station_info_2022-07-31.csv'),
#  WindowsPath('../../data/station_info_2022-08-01.csv'),
#  WindowsPath('../../data/station_info_2022-08-02.csv'),
#  WindowsPath('../../data/station_info_2022-08-03.csv'),
#  WindowsPath('../../data/station_info_2022-08-04.csv'),
#  WindowsPath('../../data/station_info_2022-08-05.csv'),
#  WindowsPath('../../data/station_info_2022-08-06.csv'),
#  WindowsPath('../../data/station_info_2022-08-07.csv'),
#  WindowsPath('../../data/station_info_2022-08-08.csv'),
#  WindowsPath('../../data/station_info_2022-08-09.csv'),
#  WindowsPath('../../data/station_info_2022-08-10.csv'),
#  WindowsPath('../../data/station_info_2022-08-11.csv'),
#  WindowsPath('../../data/station_info_2022-08-12.csv'),
#  WindowsPath('../../data/station_info_2022-08-13.csv'),
#  WindowsPath('../../data/station_info_2022-08-14.csv'),
#  WindowsPath('../../data/station_info_2022-08-15.csv'),
#  WindowsPath('../../data/station_info_2022-08-16.csv'),
#  WindowsPath('../../data/station_info_2022-08-17.csv'),
#  WindowsPath('../../data/station_info_2022-08-18.csv'),
#  WindowsPath('../../data/station_info_2022-08-19.csv'),
#  WindowsPath('../../data/station_info_2022-08-20.csv'),
#  WindowsPath('../../data/station_info_2022-08-21.csv'),
#  WindowsPath('../../data/station_info_2022-08-22.csv'),
#  WindowsPath('../../data/station_info_2022-08-23.csv'),
#  WindowsPath('../../data/station_info_2022-08-24.csv'),
#  WindowsPath('../../data/station_info_2022-08-25.csv'),
#  WindowsPath('../../data/station_info_2022-08-26.csv'),
#  WindowsPath('../../data/station_info_2022-08-27.csv'),
#  WindowsPath('../../data/station_info_2022-08-28.csv'),
#  WindowsPath('../../data/station_info_2022-08-29.csv'),
#  WindowsPath('../../data/station_info_2022-08-30.csv'),
#  WindowsPath('../../data/station_info_2022-08-31.csv'),
#  WindowsPath('../../data/station_info_2022-09-01.csv'),
#  WindowsPath('../../data/station_info_2022-09-02.csv'),
#  WindowsPath('../../data/station_info_2022-09-03.csv'),
#  WindowsPath('../../data/station_info_2022-09-04.csv'),
#  WindowsPath('../../data/station_info_2022-09-05.csv'),
#  WindowsPath('../../data/station_info_2022-09-06.csv'),
#  WindowsPath('../../data/station_info_2022-09-07.csv'),
#  WindowsPath('../../data/station_info_2022-09-08.csv'),
#  WindowsPath('../../data/station_info_2022-09-09.csv'),
#  WindowsPath('../../data/station_info_2022-09-10.csv'),
#  WindowsPath('../../data/station_info_2022-09-11.csv'),
#  WindowsPath('../../data/station_info_2022-09-12.csv'),
#  WindowsPath('../../data/station_info_2022-09-13.csv'),
#  WindowsPath('../../data/station_info_2022-09-14.csv'),
#  WindowsPath('../../data/station_info_2022-09-15.csv'),
#  WindowsPath('../../data/station_info_2022-09-16.csv'),
#  WindowsPath('../../data/station_info_2022-09-17.csv'),
#  WindowsPath('../../data/station_info_2022-09-18.csv'),
#  WindowsPath('../../data/station_info_2022-09-19.csv'),
#  WindowsPath('../../data/station_info_2022-09-20.csv'),
#  WindowsPath('../../data/station_info_2022-09-21.csv'),
#  WindowsPath('../../data/station_info_2022-09-22.csv'),
#  WindowsPath('../../data/station_info_2022-09-23.csv'),
#  WindowsPath('../../data/station_info_2022-09-24.csv'),
#  WindowsPath('../../data/station_info_2022-09-25.csv'),
#  WindowsPath('../../data/station_info_2022-09-26.csv'),
#  WindowsPath('../../data/station_info_2022-09-27.csv'),
#  WindowsPath('../../data/station_info_2022-09-28.csv'),
#  WindowsPath('../../data/station_info_2022-09-29.csv'),
#  WindowsPath('../../data/station_info_2022-09-30.csv'),
#  WindowsPath('../../data/station_info_2022-10-01.csv'),
#  WindowsPath('../../data/station_info_2022-10-02.csv'),
#  WindowsPath('../../data/station_info_2022-10-03.csv'),
#  WindowsPath('../../data/station_info_2022-10-04.csv'),
#  WindowsPath('../../data/station_info_2022-10-05.csv'),
#  WindowsPath('../../data/station_info_2022-10-06.csv'),
#  WindowsPath('../../data/station_info_2022-10-07.csv'),
#  WindowsPath('../../data/station_info_2022-10-08.csv'),
#  WindowsPath('../../data/station_info_2022-10-09.csv'),
#  WindowsPath('../../data/station_info_2022-10-10.csv'),
#  WindowsPath('../../data/station_info_2022-10-11.csv'),
#  WindowsPath('../../data/station_info_2022-10-12.csv'),
#  WindowsPath('../../data/station_info_2022-10-13.csv'),
#  WindowsPath('../../data/station_info_2022-10-14.csv'),
#  WindowsPath('../../data/station_info_2022-10-15.csv'),
#  WindowsPath('../../data/station_info_2022-11-07.csv'),
#  WindowsPath('../../data/station_info_2022-11-08.csv'),
#  WindowsPath('../../data/station_info_2022-11-09.csv'),
#  WindowsPath('../../data/station_info_2022-11-10.csv'),
#  WindowsPath('../../data/station_info_2022-11-11.csv'),
#  WindowsPath('../../data/station_info_2022-11-12.csv'),
#  WindowsPath('../../data/station_info_2022-11-13.csv'),
#  WindowsPath('../../data/station_info_2022-11-14.csv'),
#  WindowsPath('../../data/station_info_2022-11-15.csv'),
#  WindowsPath('../../data/station_info_2022-11-16.csv'),
#  WindowsPath('../../data/station_info_2022-11-17.csv'),
#  WindowsPath('../../data/station_info_2022-11-18.csv'),
#  WindowsPath('../../data/station_info_2022-11-19.csv'),
#  WindowsPath('../../data/station_info_2022-11-20.csv'),
#  WindowsPath('../../data/station_info_2022-11-21.csv'),
#  WindowsPath('../../data/station_info_2022-11-22.csv'),
#  WindowsPath('../../data/station_info_2022-11-23.csv'),
#  WindowsPath('../../data/station_info_2022-11-24.csv'),
#  WindowsPath('../../data/station_info_2022-11-25.csv'),
#  WindowsPath('../../data/station_info_2022-11-26.csv'),
#  WindowsPath('../../data/station_info_2022-11-27.csv'),
#  WindowsPath('../../data/station_info_2022-11-28.csv'),
#  WindowsPath('../../data/station_info_2022-11-29.csv'),
#  WindowsPath('../../data/station_info_2022-11-30.csv'),
#  WindowsPath('../../data/station_info_2022-12-01.csv'),
#  WindowsPath('../../data/station_info_2022-12-02.csv'),
#  WindowsPath('../../data/station_info_2022-12-03.csv'),
#  WindowsPath('../../data/station_info_2022-12-04.csv'),
#  WindowsPath('../../data/station_info_2022-12-05.csv'),
#  WindowsPath('../../data/station_info_2022-12-06.csv'),
#  WindowsPath('../../data/station_info_2022-12-07.csv'),
#  WindowsPath('../../data/station_info_2022-12-08.csv'),
#  WindowsPath('../../data/station_info_2022-12-09.csv'),
#  WindowsPath('../../data/station_info_2022-12-10.csv'),
#  WindowsPath('../../data/station_info_2022-12-11.csv'),
#  WindowsPath('../../data/station_info_2022-12-12.csv'),
#  WindowsPath('../../data/station_info_2022-12-13.csv'),
#  WindowsPath('../../data/station_info_2022-12-14.csv'),
#  WindowsPath('../../data/station_info_2022-12-15.csv'),
#  WindowsPath('../../data/station_info_2022-12-16.csv'),
#  WindowsPath('../../data/station_info_2022-12-17.csv'),
#  WindowsPath('../../data/station_info_2022-12-18.csv'),
#  WindowsPath('../../data/station_info_2022-12-19.csv'),
#  WindowsPath('../../data/station_info_2022-12-21.csv'),
#  WindowsPath('../../data/station_info_2022-12-29.csv'),
#  WindowsPath('../../data/station_info_2022-12-30.csv'),
#  WindowsPath('../../data/station_info_2022-12-31.csv'),
#  WindowsPath('../../data/station_info_2023-01-01.csv'),
#  WindowsPath('../../data/station_info_2023-01-02.csv'),
#  WindowsPath('../../data/station_info_2023-01-03.csv'),
#  WindowsPath('../../data/station_info_2023-01-04.csv'),
#  WindowsPath('../../data/station_info_2023-01-05.csv'),
#  WindowsPath('../../data/station_info_2023-01-06.csv'),
#  WindowsPath('../../data/station_info_2023-01-07.csv'),
#  WindowsPath('../../data/station_info_2023-01-08.csv'),
#  WindowsPath('../../data/station_info_2023-01-09.csv'),
#  WindowsPath('../../data/station_info_2023-01-10.csv'),
#  WindowsPath('../../data/station_info_2023-01-11.csv'),
#  WindowsPath('../../data/station_info_2023-01-12.csv'),
#  WindowsPath('../../data/station_info_2023-01-13.csv'),
#  WindowsPath('../../data/station_info_2023-01-14.csv'),
#  WindowsPath('../../data/station_info_2023-01-15.csv'),
#  WindowsPath('../../data/station_info_2023-01-16.csv'),
#  WindowsPath('../../data/station_info_2023-01-17.csv'),
#  WindowsPath('../../data/station_info_2023-01-18.csv'),
#  WindowsPath('../../data/station_info_2023-01-19.csv'),
#  WindowsPath('../../data/station_info_2023-01-20.csv'),
#  WindowsPath('../../data/station_info_2023-01-21.csv'),
#  WindowsPath('../../data/station_info_2023-01-22.csv'),
#  WindowsPath('../../data/station_info_2023-01-23.csv'),
#  WindowsPath('../../data/station_info_2023-01-24.csv'),
#  WindowsPath('../../data/station_info_2023-01-25.csv'),
#  WindowsPath('../../data/station_info_2023-01-26.csv'),
#  WindowsPath('../../data/station_info_2023-01-27.csv'),
#  WindowsPath('../../data/station_info_2023-01-28.csv'),
#  WindowsPath('../../data/station_info_2023-01-29.csv'),
#  WindowsPath('../../data/station_info_2023-01-30.csv'),
#  WindowsPath('../../data/station_info_2023-01-31.csv'),
#  WindowsPath('../../data/station_info_2023-02-01.csv'),
#  WindowsPath('../../data/station_info_2023-02-02.csv'),
#  WindowsPath('../../data/station_info_2023-02-03.csv'),
#  WindowsPath('../../data/station_info_2023-02-04.csv'),
#  WindowsPath('../../data/station_info_2023-02-05.csv'),
#  WindowsPath('../../data/station_info_2023-02-06.csv'),
#  WindowsPath('../../data/station_info_2023-02-07.csv'),
#  WindowsPath('../../data/station_info_2023-02-08.csv'),
#  WindowsPath('../../data/station_info_2023-02-09.csv'),
#  WindowsPath('../../data/station_info_2023-02-10.csv'),
#  WindowsPath('../../data/station_info_2023-02-11.csv'),
#  WindowsPath('../../data/station_info_2023-02-12.csv'),
#  WindowsPath('../../data/station_info_2023-02-13.csv'),
#  WindowsPath('../../data/station_info_2023-02-14.csv'),
#  WindowsPath('../../data/station_info_2023-02-15.csv'),
#  WindowsPath('../../data/station_info_2023-02-16.csv'),
#  WindowsPath('../../data/station_info_2023-02-17.csv'),
#  WindowsPath('../../data/station_info_2023-02-18.csv'),
#  WindowsPath('../../data/station_info_2023-02-19.csv'),
#  WindowsPath('../../data/station_info_2023-02-20.csv'),
#  WindowsPath('../../data/station_info_2023-02-21.csv')]

# %%
def get_station_info(file_path):
    """ Get station info from path + add date from path 
    
    Arg:
        * file_path (str) in format "*/station_info_YYYY-MM-DD.csv"

    """
    names = ["stationCode", "name", "capacity", 
             "station_geo", "credit_card"]
    
    df = pd.read_csv(file_path)
    #df = pd.read_csv(file_path, names = names, index_col="stationCode")

    date = str(file_path)[-14:-4]
    df["date"] = pd.to_datetime(date)
    df["stationCode"] = df["stationCode"].astype("string")

    return df.set_index("stationCode")

# %%
get_station_info(station_infos_list[5])
# Out:
#                                         station_name  capacity  \
# stationCode
# 10001                        René Boulanger - Lancry        62
# 10003                    Hauteville - Bonne Nouvelle        17
# 10004                    Metz - Faubourg Saint-Denis        48
# 10005        Petites Ecuries - Faubourg Poissonnière        17
# 10006         Petites Ecuries - Faubourg Saint-Denis        28
# ...                                              ...       ...
# 92004                          Nanterre - Université        20
# 92005                         Gare de Nanterre Ville        43
# 92006                           Place Nelson Mandela        30
# 92007                            Pesaro - Préfecture        22
# 92008                     Hôtel de Ville de Nanterre        38
#
#                   station_geo  credit_card       date
# stationCode
# 10001        48.86854,2.36000         True 2022-05-20
# 10003        48.87077,2.34965         True 2022-05-20
# 10004        48.87089,2.35352         True 2022-05-20
# 10005        48.87397,2.34839        False 2022-05-20
# 10006        48.87287,2.35422         True 2022-05-20
# ...                       ...          ...        ...
# 92004        48.90136,2.21269         True 2022-05-20
# 92005        48.89503,2.19579         True 2022-05-20
# 92006        48.89787,2.21828        False 2022-05-20
# 92007        48.89577,2.22391         True 2022-05-20
# 92008        48.89237,2.20555         True 2022-05-20
#
# [1438 rows x 5 columns]

# %%
get_station_info(station_infos_list[5]).index
# Out:
# Index(['10001', '10003', '10004', '10005', '10006', '10008', '10009', '1001',
#        '10010', '10011',
#        ...
#        '9117', '9118', '92001', '92002', '92003', '92004', '92005', '92006',
#        '92007', '92008'],
#       dtype='string', name='stationCode', length=1438)

# %%
def get_station_capacity():
    """ Dataframe with all capacities """

    capacity_df = pd.concat([get_station_info(path) for path in station_infos_list[5:]])

    return capacity_df

# %%
capacity_df = get_station_capacity()

# %%
capacity_df
# Out:
#                                         station_name  capacity  \
# stationCode
# 10001                        René Boulanger - Lancry        62
# 10003                    Hauteville - Bonne Nouvelle        17
# 10004                    Metz - Faubourg Saint-Denis        48
# 10005        Petites Ecuries - Faubourg Poissonnière        17
# 10006         Petites Ecuries - Faubourg Saint-Denis        28
# ...                                              ...       ...
# 92004                          Nanterre - Université        20
# 92005                         Gare de Nanterre Ville        43
# 92006                           Place Nelson Mandela        30
# 92007                            Pesaro - Préfecture        22
# 92008                     Hôtel de Ville de Nanterre        38
#
#                   station_geo  credit_card       date
# stationCode
# 10001        48.86854,2.36000         True 2022-05-20
# 10003        48.87077,2.34965         True 2022-05-20
# 10004        48.87089,2.35352         True 2022-05-20
# 10005        48.87397,2.34839        False 2022-05-20
# 10006        48.87287,2.35422         True 2022-05-20
# ...                       ...          ...        ...
# 92004        48.90136,2.21269         True 2023-02-21
# 92005        48.89503,2.19579         True 2023-02-21
# 92006        48.89787,2.21828        False 2023-02-21
# 92007        48.89577,2.22391         True 2023-02-21
# 92008        48.89237,2.20555         True 2023-02-21
#
# [358200 rows x 5 columns]

# %%
raw_labels
# Out:
#                           stationCode  available_mechanical  \
# file_time
# 2022-05-20 09:30:08+02:00        5001                   0.0
# 2022-05-20 09:30:08+02:00       20044                   1.0
# 2022-05-20 09:30:08+02:00       14031                   1.0
# 2022-05-20 09:30:08+02:00        6002                   1.0
# 2022-05-20 09:30:08+02:00       41401                  13.0
# ...                               ...                   ...
# 2023-02-11 09:30:08+01:00       19038                   0.0
# 2023-02-11 09:30:08+01:00       18109                  11.0
# 2023-02-11 09:30:08+01:00       19009                   3.0
# 2023-02-11 09:30:08+01:00       10020                   0.0
# 2023-02-11 09:30:08+01:00       16107                   0.0
#
#                            available_electrical  local_hour  local_minute  \
# file_time
# 2022-05-20 09:30:08+02:00                   1.0           9            30
# 2022-05-20 09:30:08+02:00                   2.0           9            30
# 2022-05-20 09:30:08+02:00                   1.0           9            30
# 2022-05-20 09:30:08+02:00                   0.0           9            30
# 2022-05-20 09:30:08+02:00                   1.0           9            30
# ...                                         ...         ...           ...
# 2023-02-11 09:30:08+01:00                   0.0           9            30
# 2023-02-11 09:30:08+01:00                  11.0           9            30
# 2023-02-11 09:30:08+01:00                   5.0           9            30
# 2023-02-11 09:30:08+01:00                   3.0           9            30
# 2023-02-11 09:30:08+01:00                   2.0           9            30
#
#                            week_day       date
# file_time
# 2022-05-20 09:30:08+02:00         4 2022-05-20
# 2022-05-20 09:30:08+02:00         4 2022-05-20
# 2022-05-20 09:30:08+02:00         4 2022-05-20
# 2022-05-20 09:30:08+02:00         4 2022-05-20
# 2022-05-20 09:30:08+02:00         4 2022-05-20
# ...                             ...        ...
# 2023-02-11 09:30:08+01:00         5 2023-02-11
# 2023-02-11 09:30:08+01:00         5 2023-02-11
# 2023-02-11 09:30:08+01:00         5 2023-02-11
# 2023-02-11 09:30:08+01:00         5 2023-02-11
# 2023-02-11 09:30:08+01:00         5 2023-02-11
#
# [340778 rows x 7 columns]

# %%
def get_available_docks(capacity_df, raw_labels):
    """"
    Dataframe with available docks
    """
    aux = capacity_df.reset_index().merge(raw_labels, how="outer", left_on=["stationCode", "date"], right_on=["stationCode", "date"])

    aux["capacity"] = pd.to_numeric(aux["capacity"], errors='coerce')

    aux["available_docks"] = aux["capacity"] - aux["available_mechanical"] - aux["available_electrical"]

    return aux

# %%
available_docks_df = get_available_docks(capacity_df, raw_labels)

# %%
capacity_df.index
# Out:
# Index(['10001', '10003', '10004', '10005', '10006', '10008', '10009', '1001',
#        '10010', '10011',
#        ...
#        '9117', '9118', '92001', '92002', '92003', '92004', '92005', '92006',
#        '92007', '92008'],
#       dtype='string', name='stationCode', length=358200)

# %%
# Objectif maintenant : calculer le nombre de places disponibles !
# Une option : un simple join sur "stationCode" et "date" !

# %%
label_cols = ["available_docks", "date", "stationCode"]

label_by_date = available_docks_df[label_cols].pivot(index=["date"], columns=["stationCode"])

# %%
label_by_date
# Out:
#             available_docks                                                  \
# stationCode           10001 10003 10004 10005 10006 10008 10009 1001  10010
# date
# 2022-05-20             62.0  14.0  43.0  11.0  23.0  13.0  18.0  13.0  29.0
# 2022-05-21             48.0  15.0  43.0  12.0  25.0  14.0  15.0  13.0  11.0
# 2022-05-22             54.0  16.0  42.0  13.0  20.0  12.0  17.0  14.0  27.0
# 2022-05-23             58.0  13.0  43.0   6.0  12.0  18.0  17.0  10.0  32.0
# 2022-05-24             54.0   8.0  33.0   2.0  22.0  17.0  17.0   6.0  29.0
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2023-02-17              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-18              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-19              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-20              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-21              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                    ...                                                        \
# stationCode 10011  ... 9117  9118  92001 92002 92003 92004 92005 92006 92007
# date               ...
# 2022-05-20   12.0  ...  29.0  35.0  20.0  14.0   7.0  15.0  39.0  29.0  18.0
# 2022-05-21    7.0  ...  29.0  35.0  20.0  14.0   7.0  17.0  37.0  27.0  18.0
# 2022-05-22   16.0  ...  21.0  35.0  19.0  18.0   5.0  17.0  41.0  18.0  18.0
# 2022-05-23   11.0  ...  31.0  36.0  20.0  11.0  19.0  14.0  41.0  19.0   4.0
# 2022-05-24   14.0  ...  31.0  35.0  20.0  11.0  15.0  14.0  39.0  19.0   9.0
# ...           ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2023-02-17    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-18    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-19    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-20    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-02-21    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#
# stationCode 92008
# date
# 2022-05-20   11.0
# 2022-05-21   11.0
# 2022-05-22   14.0
# 2022-05-23    7.0
# 2022-05-24   10.0
# ...           ...
# 2023-02-17    NaN
# 2023-02-18    NaN
# 2023-02-19    NaN
# 2023-02-20    NaN
# 2023-02-21    NaN
#
# [249 rows x 1468 columns]

# %%
label_by_date.loc["2023-02-11"].notnull().sum()
# Out:
# 1453

# %%
label_by_date.loc["2023-02-12"].notnull().sum()
# Out:
# 0
